# %% [markdown]
# <a href="https://colab.research.google.com/github/najmaosman937-del/Najma_INFO5731_Fall2024/blob/main/najma_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# My First Python Code in Google Colab
print("Hello, Google Colab!")
print("My name is Najma")
print("This is my INFO 5731 repository")

# Basic arithmetic operations
x = 10
y = 5

print(f"\nBasic Math Operations:")
print(f"{x} + {y} = {x + y}")
print(f"{x} - {y} = {x - y}")
print(f"{x} * {y} = {x * y}")
print(f"{x} / {y} = {x / y}")

# Working with lists
my_courses = ["INFO 5731", "Data Science", "Machine Learning"]
print(f"\nMy courses: {my_courses}")
print(f"Number of courses: {len(my_courses)}")

# Simple loop
print("\nCounting to 5:")
for i in range(1, 6):
    print(f"Number {i}")

print("\n✓ Code executed successfully!")
# Out:
# Hello, Google Colab!
# My name is Najma
# This is my INFO 5731 repository
#
# Basic Math Operations:
# 10 + 5 = 15
# 10 - 5 = 5
# 10 * 5 = 50
# 10 / 5 = 2.0
#
# My courses: ['INFO 5731', 'Data Science', 'Machine Learning']
# Number of courses: 3
#
# Counting to 5:
# Number 1
# Number 2
# Number 3
# Number 4
# Number 5
#
# ✓ Code executed successfully!
